# %%
from scipy.spatial.transform import Rotation
import numpy as np
import mpmath as mp
from orbit3d import plot_3dtraj, _twodim_params, _rotation_matrix, _rotate_r, _rotate, get_3dtrajectory
from orbit2d import get_2dtrajectory
mp.mp.dps = 50

# %%
rin = mp.matrix([1e20, 6e3, 0])
vin = mp.matrix([-200, 0., 0])
k = 1.32712e11

# %%
(thetamin, thetamax), xs, vs, ts = get_3dtrajectory(rin, vin, k)
thetas = mp.linspace(thetamin, thetamax, 10_000)[1:-1]

# %%
xs(thetas)
# Out:
# array([[mpf('8140370.6626790959015536402323519260780024972544790749'),
#         mpf('5112.3133872082287990606843521115384737446071971531117'),
#         mpf('0.0')],
#        [mpf('3545617.4341760068977949756673551607001830626867819294'),
#         mpf('4453.4371651988049364511894344242042563801103065596378'),
#         mpf('0.0')],
#        [mpf('2093883.1183333891637187594535473664500995232078913225'),
#         mpf('3945.0038822495312004810509933215820631617337308408978'),
#         mpf('0.0')],
#        ...,
#        [mpf('2093855.1542104268532972324782585660006180748526034556'),
#         mpf('-11518.223978476567928859347707550518283668410173731946'),
#         mpf('0.0')],
#        [mpf('3545578.1356303740946705239784125693804873765896844094'),
#         mpf('-17277.34861822095043186179515446611424096366142272795'),
#         mpf('0.0')],
#        [mpf('8140298.9277336744553829092023908669291371416420561798'),
#         mpf('-34554.720266005438149017062771271077695230692704336827'),
#         mpf('0.0')]], dtype=object)

# %%
ts(thetas)
# Out:
# array([mpf('499999999999483671.72899602904333045440257427716998067'),
#        mpf('499999999999499257.43882188885217337637795256070924469'),
#        mpf('499999999999503206.60265101297236858967406721826524491'), ...,
#        mpf('499999999999510410.29828877460938141757344687947934168'),
#        mpf('499999999999514359.4621178987295766308695615370353419'),
#        mpf('499999999999529945.17194375853841955284493982057460592')],
#       dtype=object)

# %%
plot_3dtraj(rin, vin, k, filepath='test.html')

# %%
vs(thetas)
# Out:
# array([[mpf('-269.45478166382814187336319314931322206179600295507487'),
#         mpf('-0.021809484469940498814476882737725878123260365344598268'),
#         mpf('0.0')],
#        [mpf('-338.90953593409521676345979827247590904128718416523527'),
#         mpf('-0.087237929277912344683868098264629066433601019005554389'),
#         mpf('0.0')],
#        [mpf('-408.36423541723769074748592686484979234892165706114108'),
#         mpf('-0.19628530861836997853009115823805467474589481931968245'),
#         mpf('0.0')],
#        ...,
#        [mpf('408.36085445658410879879557898904078548015531895899332'),
#         mpf('-1.673273234124056943822603676522869976584048165794265'),
#         mpf('0.0')],
#        [mpf('338.90700366975095259201017153394955275736782517762046'),
#         mpf('-1.3130198442887454523304754767652375529350804190964331'),
#         mpf('0.0')],
#        [mpf('269.45294033332600765553488458746517762719160403705534'),
#         mpf('-0.99638490552691126796601884938382805416002699004976968'),
#         mpf('0.0')]], dtype=object)
