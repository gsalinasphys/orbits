# %%
from scipy.spatial.transform import Rotation
import numpy as np
from orbit3d import get_3dtrajectory, plot_3dtraj

# %%
rin, vin = np.array([1.e5, 10, 0]), np.array([-200, 0, 1e-6])

# %%
k = 1.
(thetai, thetaf), xs, ts = get_3dtrajectory(rin, vin, k)

# %%
thetas = np.linspace(thetai, thetaf, 100)

# %%
plot_3dtraj(rin, vin, k, filepath='test.html')
