# %%
from scipy.spatial.transform import Rotation
import numpy as np
import mpmath as mp
from orbit3d import get_3dtrajectory, plot_3dtraj, _rotation
mp.mp.dps = 50

# %%
rin, vin = np.array([1.e20, 6e3, 0.]), np.array([-200., 0., 0.])

# %%
k = 1.
(thetai, thetaf), xs, ts = get_3dtrajectory(rin, vin, k)
# Out:
# /home/gsalinas/GitHub/orbits/orbit3d.py:17: UserWarning:
#
# Optimal rotation is not uniquely or poorly defined for the given sets of vectors.

# %%
thetas = mp.linspace(thetai, thetaf, 100)

# %%
xs(thetas)
# Out:
# array([[ 1.00000000e+20,  6.00000000e+03,  0.00000000e+00],
#        [ 1.89012601e+05,  6.00000000e+03,  0.00000000e+00],
#        [ 9.44110688e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 6.28348426e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 4.70148788e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 3.74973479e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 3.11309560e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 2.65651334e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 2.31245819e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 2.04341234e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 1.82686400e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 1.64848645e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 1.49872754e+04,  6.00000000e+03,  0.00000000e+00],
#        [ 1.37097333e+04,  5.99999999e+03,  0.00000000e+00],
#        [ 1.26049868e+04,  5.99999999e+03,  0.00000000e+00],
#        [ 1.16383763e+04,  5.99999999e+03,  0.00000000e+00],
# ...

# %%
ts(thetas)
# Out:
# array([mpf('0.0'),
#        mpf('499999999999999054.93699038933783019990874862664975745'),
#        mpf('499999999999999527.94465181229435808721303241082638049'),
#        mpf('499999999999999685.82578279633546364335893927158142139'),
#        mpf('499999999999999764.92560180521651015232136662803473319'),
#        mpf('499999999999999812.51325616637116694401054686048319533'),
#        mpf('499999999999999844.34521555484512224942986881441429766'),
#        mpf('499999999999999867.17432842459948207111068032928460193'),
#        mpf('499999999999999884.37708631354999772512473123056362354'),
#        mpf('499999999999999897.8293787926332847660137850232584771'),
#        mpf('499999999999999908.6567956138741220389300816089016233'),
#        mpf('499999999999999917.57567330064025607608774085615385773'),
#        mpf('499999999999999925.06361859538732463540038980755309473'),
#        mpf('499999999999999931.45132892552429256826058529387845254'),
# ...

# %%
plot_3dtraj(rin, vin, k, filepath='test.html')
