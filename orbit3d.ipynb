# %%
from scipy.spatial.transform import Rotation
import numpy as np
import mpmath as mp
from orbit3d import plot_3dtraj, _rotation_matrix, _rotate, get_3dtrajectory
from orbit2d import get_2dtrajectory
mp.mp.dps = 50

# %%
r0 = mp.matrix([1e20, -6e3, 0])
v0 = mp.matrix([-200, 0., 0])
k = 1.32712e11

# %%
(thetamin, thetamax), r, v, t = get_3dtrajectory(r0, v0, k)
thetas = mp.linspace(thetamin, thetamax, 10_000)[1:-1]

# %%
rs = [r(theta) for theta in thetas]
rs
# Out:
# [matrix(
#  [['8140298.9277336744595294756343114608968669094921526'],
#   ['34554.720266004461313145734730336182952140490564585'],
#   ['0.0']]),
#  matrix(
#  [['3545578.1356303740967438058125990579041482154695268'],
#   ['17277.348618220524962485519509574629381176200725055'],
#   ['0.0']]),
#  matrix(
#  [['2093855.1542104268546794193556757390763240862624362'],
#   ['11518.223978476316666240842456328039684558374115429'],
#   ['0.0']]),
#  matrix(
#  [['1409471.8108255669694422869679432601006447397021563'],
#   ['8638.6610907419306078765780203904238465179941777293'],
#   ['0.0']]),
#  matrix(
#  [['1022771.948391863794377510581574376935350141354569'],
#   ['6910.9229038113491318246803139990951376149700317721'],
#   ['0.0']]),
#  matrix(
#  [['779826.26228937750818582307468632015661685382754007'],
#   ['5759.0970672825361754668537628107814053964809800049'],
#   ['0.0']]),
#  matrix(
#  [['616032.15540979863505314482724653634265322909228261'],
# ...

# %%
ts = [t(theta) for theta in thetas]
ts
# Out:
# [mpf('499999999999529945.17194375853841955284493982057460361'),
#  mpf('499999999999514359.46211789872957663086956153703533881'),
#  mpf('499999999999510410.29828877460938141757344687947933937'),
#  mpf('499999999999508849.684179928460972591598830156740991'),
#  mpf('499999999999508089.72700475995940340088458894684370407'),
#  mpf('499999999999507670.03345919234330517306358072780333067'),
#  mpf('499999999999507417.54699941963695766200737658556360225'),
#  mpf('499999999999507255.84243524335757472104778670038753299'),
#  mpf('499999999999507147.18063229013943301349055587999467604'),
#  mpf('499999999999507071.31758797208104271621518044929645169'),
#  mpf('499999999999507016.67399277846093953898018340978059332'),
#  mpf('499999999999506976.27684878790363997063705465757282641'),
#  mpf('499999999999506945.7456080285621155287691101010506307'),
#  mpf('499999999999506922.22898716644701352427841727201868508'),
#  mpf('499999999999506903.81416614550168828360307833471922458'),
# ...

# %%
plot_3dtraj(r0, v0, k, filepath='test.html')

# %%
vs = [v(theta) for theta in thetas]
vs
# Out:
# [matrix(
#  [['269.45294033332600777510107325069258972194346601527'],
#   ['0.99638490552687893361317885026290221600255670057851'],
#   ['0.0']]),
#  matrix(
#  [['338.907003669750952749572552848596566906598460182'],
#   ['1.313019844288704783490035106650917057971617466323'],
#   ['0.0']]),
#  matrix(
#  [['408.36085445658410899958836708392467854071567273675'],
#   ['1.6732732341240079405200688864298020735472837878699'],
#   ['0.0']]),
#  matrix(
#  [['477.81446530062491989721888930936075773505079275967'],
#   ['2.0771449329457299167329765449331358885148605256761'],
#   ['0.0']]),
#  matrix(
#  [['547.26780880876746433090070158534259390767614249385'],
#   ['2.5246347814633732143742479731611364557154517779102'],
#   ['0.0']]),
#  matrix(
#  [['616.72085758801126078376868072078572879123238424045'],
#   ['3.0157426031830641514576059197327012805916724596117'],
#   ['0.0']]),
#  matrix(
#  [['686.17358424547207137040179454789104522716311205303'],
# ...
